# %% [markdown]
# **Database Systems 2017 (ITWS-6960)**
#
# **Final Project**
#
# **Stephan Zednik**

# %%
import re
import pandas
import matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# # Recipe Data

# %%
from recipes import RecipeData

# %% [markdown]
# Open a connection to the recipes database

# %%
recipes = RecipeData()
recipes.is_connected()
# Out:
# True

# %% [markdown]
# Use the ``RecipeData`` fluent interface to query recipe data from MongoDB

# %% [markdown]
# *query - find 5 recipes for alcoholic eggnog that are under 400 calories*

# %%
recipes.query().title_contains("eggnog").category("alcoholic").max_calories(400).run().head(5)
# Out:
#                         _id  calories  \
# 0  5a232c6de6136c4edf871886     264.0
# 1  5a232c6de6136c4edf8725a5     203.0
# 2  5a232c6de6136c4edf8737da     378.0
# 3  5a232c6de6136c4edf87393f     232.0
# 4  5a232c6de6136c4edf873c35     296.0
#
#                                           categories  \
# 0  [Milk/Cream, Egg Nog, Non-Alcoholic, Egg, Chri...
# 1  [Bourbon, Liqueur, Milk/Cream, Rum, Alcoholic,...
# 2  [Milk/Cream, Rum, Egg Nog, Alcoholic, Egg, Chr...
# 3  [Milk/Cream, Rum, Egg Nog, Alcoholic, Egg, Chr...
# 4  [Milk/Cream, Rum, Alcoholic, Mixer, Egg, Chris...
#
#                        date  desc  \
# 0  2004-08-20T20:58:12.000Z  None
# 1  2004-08-20T20:58:12.000Z  None
# 2  2004-08-20T20:58:12.000Z  None
# 3  2004-08-20T20:58:12.000Z  None
# 4  2004-08-20T20:58:12.000Z  None
#
#                                           directions   fat  \
# 0  [Beat the egg with the sugar and salt and pour...  12.0
# 1  [Beat the egg yolks until they are light and g...   8.0
# 2  [Beat egg yolks until they are thick and pale ...  29.0
# 3  [Beat the egg yolks and sugar together until t...   9.0
# 4  [In the bowl of an electric mixer, dissolve th...   8.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [1 whole egg, 1 tablespoon superfine sugar, Pi...     12.0    2.50   450.0
# 1  [12 egg yolks, 1 cup fine granulated sugar, Cr...      1.0    0.00    18.0
# 2  [12 egg yolks, 2 1/2 cups sugar, 3 quarts heav...      2.0    0.00    31.0
# 3  [12 eggs, separated, 2 cups superfine sugar, 1...      4.0    5.00    52.0
# 4  [1 cup honey, 1 cup warm water, 1 cup light ru...      2.0    3.75    26.0
#
#                title
# 0            Eggnog
# 1         Eggnoggin
# 2     Frozen Eggnog
# 3  Baltimore Eggnog
# 4      Honey Eggnog

# %% [markdown]
# The ``.show()`` method can be used with the fluent interface to show what the compiled pymongo query looks like

# %%
recipes.query().title_contains("eggnog").category("alcoholic").max_calories(400).show()
# Out:
# {'calories': {'$lte': 400},
#  'categories': re.compile(r'alcoholic', re.IGNORECASE|re.UNICODE),
#  'title': re.compile(r'eggnog', re.IGNORECASE|re.UNICODE)}

# %% [markdown]
# # Product Data

# %%
from products import ProductData

# %% [markdown]
# Open a connection to the products database

# %%
products = ProductData("host='localhost' dbname='foodfacts' user='foodfacts' password='foodfacts'")

# %% [markdown]
# Use the ``ProductData`` fluent interface to query for product data from the PostgreSQL db

# %% [markdown]
# *query - find Kroger-brand products whose name includes 'Enriched Flour'*

# %%
products.query().name_includes("Enriched Flour").brand("Kroger").run()
# Out:
#   allergens  brands calories_100g calories_from_fat_100g carbohydrates_100g  \
# 0        {}  Kroger        1393.0                   None              73.33
# 1        {}  Kroger        1393.0                   None              73.33
#
#           code fat_100g                                   name protein_100g  \
# 0  11110854018     0.00    Bleached All Purpose Enriched Flour        10.00
# 1  11110861160     0.00  Unbleached All Purpose Enriched Flour        10.00
#
#   saturated_fat_100g sugars_100g  \
# 0               0.00        3.33
# 1               0.00        3.33
#
#                                                  url
# 0  http://world-en.openfoodfacts.org/product/0011...
# 1  http://world-en.openfoodfacts.org/product/0011...

# %% [markdown]
# As with the ``RecipeData`` API, the ``.show()`` method can be used to show the SQL query that would be executed against the PostgreSQL db for a given query construction.

# %%
products.query().name_includes("Enriched Flour").brand("Kroger").show()
# Out:
# b"SELECT DISTINCT products.* from products WHERE LOWER(products.name) like LOWER('%Enriched Flour%') AND LOWER(brands) like LOWER('%Kroger%') ORDER BY products.code"

# %% [markdown]
# The fluent API supports some method being called multiple times so a query can indicate that more than 1 category for a given product should be matched against.  This is treated as an AND over the constraints.
#
# The ProductData API does not currently support the ability to provide OR over multiple values, but this could be added at a later time.

# %%
products.query().category("alcoholic").category("christmas").max_calories(500).show()
# Out:
# b"SELECT DISTINCT products.* from products JOIN product_category as product_category0 on products.code = product_category0.product JOIN categories as categories0 on categories0.name = product_category0.category JOIN product_category as product_category1 on products.code = product_category1.product JOIN categories as categories1 on categories1.name = product_category1.category WHERE LOWER(categories0.name) like LOWER('%alcoholic%') AND LOWER(categories1.name) like LOWER('%christmas%') AND products.calories_100g <= 500 ORDER BY products.code"

# %%
products.query().category("alcoholic").category("christmas").max_calories(500).run()
# Out:
#   allergens brands calories_100g calories_from_fat_100g carbohydrates_100g  \
# 0        {}  Leffe         239.0                   None               5.30
#
#             code fat_100g           name protein_100g saturated_fat_100g  \
# 0  5410228201144     0.00  Bière de Noël         0.50               0.00
#
#   sugars_100g                                                url
# 0        0.30  http://world-en.openfoodfacts.org/product/5410...

# %% [markdown]
# ## SQL Injection

# %% [markdown]
# The [psycopg2](http://initd.org/psycopg/docs/usage.html#passing-parameters-to-sql-queries) library is used to escape query parameters for the purpose of defending against SQL-injection attacks.

# %% [markdown]
# *Test resistence to SQL-injection*

# %%
products.query().name_includes("'); SELECT * from products;").show()
# Out:
# b"SELECT DISTINCT products.* from products WHERE LOWER(products.name) like LOWER('%''); SELECT * from products;%') ORDER BY products.code"

# %% [markdown]
# The ``'`` of the injection is escaped so the entire injection attack is treated as a literal value instead of as part of a DQL (SELECT), DML (UPDATE, DELETE), or DDL (DROP) command

# %%
products.query().name_includes("'); SELECT * from products;").run()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
products.query().brand("); DROP products; COMMIT; ").run()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# note - I am a little surprised that the resulting DataFrame does not have columns (something I may look into later...) but a follow-up query over products will how that the ``DROP products;`` query was not sucessful.

# %%
# find all products that include peanuts
products.query().ingredient("peanut").brand("Kroger").run()
# Out:
#    allergens                         brands calories_100g  \
# 0         {}                         Kroger          None
# 1         {}  Simple Truth,  The Kroger Co.        2690.0
# 2         {}                         Kroger         916.0
# 3         {}                         Kroger        2213.0
# 4         {}                         Kroger        2389.0
# 5         {}                         Kroger        2389.0
# 6         {}                         Kroger        2389.0
# 7         {}                         Kroger        2389.0
# 8         {}                         Kroger        2540.0
# 9         {}                         Kroger        2540.0
# 10        {}                         Kroger         958.0
# 11        {}                         Kroger        1933.0
# 12        {}                         Kroger        2351.0
# 13        {}                         Kroger        2351.0
# 14        {}                         Kroger        2485.0
# 15        {}                         Kroger        2485.0
# 16        {}                         Kroger        2213.0
# 17        {}                         Kroger        2155.0
# 18        {}        Kroger,  The Kroger Co.         916.0
# 19        {}                 The Kroger Co.        2351.0
# 20        {}                 The Kroger Co.        2213.0
# 21        {}                         Kroger        2389.0
# 22        {}                Simply,  Kroger        2092.0
# 23        {}                 The Kroger Co.        2092.0
# 24        {}                         Kroger        2092.0
# 25        {}        Kroger,  The Kroger Co.        2067.0
# 26        {}        Kroger,  The Kroger Co.        2146.0
# 27        {}                         Kroger         778.0
# 28        {}                         Kroger        1197.0
# 29        {}                         Kroger         967.0
# ..       ...                            ...           ...
# 47        {}                         Kroger        2092.0
# 48        {}                         Kroger        2389.0
# 49        {}                         Kroger        2243.0
# 50        {}        Kroger,  The Kroger Co.        2389.0
# 51        {}        Kroger,  The Kroger Co.        1954.0
# 52        {}        Kroger,  The Kroger Co.        1954.0
# 53        {}        Kroger,  The Kroger Co.        1812.0
# 54        {}                 The Kroger Co.        2033.0
# 55        {}                         Kroger        1695.0
# 56        {}                         Kroger        1644.0
# 57        {}                         Kroger         812.0
# 58        {}        Kroger,  The Kroger Co.        1393.0
# 59        {}                         Kroger        1745.0
# 60        {}                         Kroger        1795.0
# 61        {}                         Kroger        1569.0
# 62        {}                 The Kroger Co.        1883.0
# 63        {}                         Kroger        2033.0
# 64        {}                         Kroger        2033.0
# 65        {}                         Kroger        1912.0
# 66        {}                 The Kroger Co.        2389.0
# 67        {}                         Kroger        2163.0
# 68        {}                         Kroger        2033.0
# 69        {}                         Kroger        2389.0
# 70        {}                         Kroger        2389.0
# 71        {}        Kroger,  The Kroger Co.        2389.0
# 72        {}                         Kroger        2540.0
# 73        {}                         Kroger        2540.0
# 74        {}                         Kroger        2197.0
# 75        {}                         Kroger        2092.0
# 76        {}                         Kroger        2197.0
#
#    calories_from_fat_100g carbohydrates_100g          code fat_100g  \
# 0                    None              21.43   01110843432    53.39
# 1                    None              17.86  011110024567    53.57
# 2                    None              26.56  011110560601    10.94
# 3                    None              32.35   11110004925    38.24
# 4                    None              28.57   11110008367    46.43
# 5                    None              28.57   11110008398    46.43
# 6                    None              28.57   11110008527    50.00
# 7                    None              28.57   11110008565    46.43
# 8                    None              17.86   11110008626    53.57
# 9                    None              17.86   11110008688    53.57
# 10                   None              31.43   11110014030    10.00
# 11                   None              57.69   11110015907    26.92
# 12                   None              25.00   11110016188    46.88
# 13                   None              28.12   11110016195    46.88
# 14                   None              21.88   11110016492    50.00
# 15                   None              21.88   11110016508    50.00
# 16                   None              29.41   11110016515    41.18
# 17                   None              57.58   11110016676    27.27
# 18                   None              26.56   11110017499    10.94
# 19                   None              25.00   11110019035    46.88
# 20                   None              32.35   11110019059    38.24
# 21                   None              14.29   11110019523    50.00
# 22                   None              46.67   11110019547    33.33
# 23                   None              56.67   11110022851    26.67
# 24                   None              50.00   11110022875    36.67
# 25                   None              44.71   11110023100    30.59
# 26                   None              53.85   11110097378    28.21
# 27                   None              30.00   11110505019     7.14
# 28                   None              30.00   11110529350    17.14
# 29                   None              35.38   11110529473     9.23
# ..                    ...                ...           ...      ...
# 47                   None              46.67   11110833303    33.33
# 48                   None              25.00   11110838575    46.43
# 49                   None              60.71   11110841629    28.57
# 50                   None              17.86   11110843432    53.57
# 51                   None              60.00   11110848642    20.00
# 52                   None              60.00   11110848673    20.00
# 53                   None              76.67   11110848789    10.00
# 54                   None              54.29   11110853059    25.71
# 55                   None              64.86   11110858092    13.51
# 56                   None              78.57   11110861894     5.36
# 57                   None              27.78   11110868091     8.33
# 58                   None              46.67   11110868428    10.00
# 59                   None              70.83   11110869500    10.42
# 60                   None              68.57   11110869661    14.29
# 61                   None              70.00   11110869715    11.25
# 62                   None              42.50   11110869784    25.00
# 63                   None              62.86   11110869968    22.86
# 64                   None              60.00   11110869975    22.86
# 65                   None              68.57   11110869982    17.14
# 66                   None              17.86   11110872098    46.43
# 67                   None              65.52   11110872388    27.59
# 68                   None              60.00   11110876737    22.86
# 69                   None              28.57   11110886439    42.86
# 70                   None              21.43   11110886453    50.00
# 71                   None              25.00   11110910066    42.86
# 72                   None              25.00   11110911124    46.43
# 73                   None              25.00   11110912220    46.43
# 74                   None              47.50   41260357831    37.50
# 75                   None              60.00   41260359040    30.00
# 76                   None              55.00   41260359064    32.50
#
#                                                  name protein_100g  \
# 0                                  Mixed Nuts, Salted         None
# 1                           Roasted Almonds, Sea Salt        21.43
# 2                                Party Pail Ice Cream         3.12
# 3                           Roasted Peanuts And Honey        17.65
# 4                      Salted Cashews Halves & Pieces        17.86
# 5             Halves & Pieces Cashews, Lightly Salted        17.86
# 6                              Unsalted Whole Cashews        17.86
# 7                      Salted Cashews Halves & Pieces        17.86
# 8                                   Salted Mixed Nuts        21.43
# 9                                   Salted Mixed Nuts        21.43
# 10          Deluxe Ice Cream, Chocolate Butter Toffee         2.86
# 11  Chipmates, Chunky Chocolate Chip Cookies, Pean...         7.69
# 12              Creamy Peanut Butter, Roasted Peanuts        21.88
# 13                              Crunchy Peanut Butter        21.88
# 14                       Natural Creamy Peanut Butter        25.00
# 15                              Crunchy Peanut Butter        25.00
# 16                  Crunchy Roasted Peanuts And Honey        20.59
# 17                              Butter Toffee Peanuts        15.15
# 18                    Party Pail Ice Cream, Chocolate         3.12
# 19                               Creamy Peanut Butter        21.88
# 20                   Roasted Peanuts And Honey Creamy        17.65
# 21               Peanuts With Sea Salt, Salt & Pepper        25.00
# 22                                  Classic Trail Mix        13.33
# 23                     Banana Toffee Crunch Trail Mix        10.00
# 24                                          Trail Mix        10.00
# 25                                     Salted Peanuts        16.47
# 26          Sandwich Crackers, Peanut Butter & Cheese        12.82
# 27  Deluxe Churned Reduced Fat Ice Cream, Peanut B...         5.71
# 28                   Deluxe Ice Cream, Triple Brownie         4.29
# 29  Deluxe Jammed Dairy Dessert, Caramel Candy Crunch         4.62
# ..                                                ...          ...
# 47                           Simply Classic Trail Mix        13.33
# 48                Honey Roasted Almonds With Sea Salt        17.86
# 49                      Mini Cheese Sandwich Crackers         7.14
# 50                        Salted Mixed Nuts, Sea Salt        21.43
# 51                Mini Filled Pretzels, Peanut Butter        13.33
# 52                Mini Filled Pretzels, Peanut Butter        13.33
# 53                           Peanut Butter Chip Mates         6.67
# 54                         Xtreme Trail Mix Chewy Bar        11.43
# 55                         Soft Baked Bars, Blueberry         2.70
# 56          Multi-Grain Toasted Cereal, Peanut Butter         7.14
# 57        Thai Inspirations, Sweet Chili Peanut Sauce         5.56
# 58                                     Pad Thai Sauce         3.33
# 59         Granola Bars, Peanut Butter Chocolate Chip         8.33
# 60                                          Trail Mix         8.57
# 61          High Fiber Oats & Peanut Butter Chewy Bar         7.50
# 62                                 Chewy Protein Bars        25.00
# 63  Sweet & Salty Pretzel Bar, Peanut Chocolate Chunk         8.57
# 64              Granola Bars Dipped In Peanut Coating        11.43
# 65                               Granola Bars, Almond         8.57
# 66                                            Peanuts        25.00
# 67               Fudge Enrobed Cookies, Peanut Butter         3.45
# 68                                       Granola Bars        11.43
# 69                        Honey & Dry Roasted Peanuts        21.43
# 70                 Dry Roasted Lightly Salted Peanuts        21.43
# 71                             Salted Roasted Peanuts        25.00
# 72                                   Unsalted Peanuts        25.00
# 73                           Unsalted Roasted Peanuts        25.00
# 74                          Chocolate Peanut Clusters        12.50
# 75                               Chocolate Bridge Mix         5.00
# 76                          Chocolate Covered Peanuts         7.50
#
#    saturated_fat_100g sugars_100g  \
# 0                7.14        None
# 1                3.57        3.57
# 2                6.25       18.75
# 3                7.35       20.59
# 4                8.93        3.57
# 5                8.93        3.57
# 6                8.93        3.57
# 7                8.93        3.57
# 8                7.14        3.57
# 9                7.14        3.57
# 10               6.43       28.57
# 11               9.62       26.92
# 12               7.81       12.50
# 13               7.81       12.50
# 14               6.25        3.12
# 15               6.25        3.12
# 16               7.35       17.65
# 17               4.55       48.48
# 18               6.25       18.75
# 19               7.81       12.50
# 20               7.35       20.59
# 21               7.14        3.57
# 22               5.00       30.00
# 23              13.33       43.33
# 24              11.67       30.00
# 25               4.71       30.59
# 26               6.41        7.69
# 27               4.29        7.14
# 28               8.57       25.71
# 29               5.38       27.69
# ..                ...         ...
# 47               5.00       30.00
# 48               3.57       14.29
# 49               7.14       10.71
# 50               7.14        3.57
# 51               3.33        3.33
# 52               3.33        3.33
# 53               1.67        3.33
# 54               5.71       37.14
# 55               5.41       24.32
# 56               0.00       32.14
# 57               0.00       27.78
# 58               0.00       40.00
# 59               2.08       29.17
# 60               1.43       31.43
# 61               5.00       17.50
# 62              10.00       17.50
# 63               8.57       31.43
# 64               7.14       28.57
# 65               5.71       31.43
# 66               7.14        3.57
# 67              13.79       37.93
# 68               8.57       28.57
# 69               5.36       14.29
# 70               7.14        3.57
# 71               7.14        3.57
# 72               8.93        3.57
# 73               8.93        3.57
# 74              15.00       40.00
# 75              20.00       50.00
# 76              20.00       50.00
#
#                                                   url
# 0   http://world-en.openfoodfacts.org/product/0111...
# 1   http://world-en.openfoodfacts.org/product/0111...
# 2   http://world-en.openfoodfacts.org/product/0111...
# 3   http://world-en.openfoodfacts.org/product/0011...
# 4   http://world-en.openfoodfacts.org/product/0011...
# 5   http://world-en.openfoodfacts.org/product/0011...
# 6   http://world-en.openfoodfacts.org/product/0011...
# 7   http://world-en.openfoodfacts.org/product/0011...
# 8   http://world-en.openfoodfacts.org/product/0011...
# 9   http://world-en.openfoodfacts.org/product/0011...
# 10  http://world-en.openfoodfacts.org/product/0011...
# 11  http://world-en.openfoodfacts.org/product/0011...
# 12  http://world-en.openfoodfacts.org/product/0011...
# 13  http://world-en.openfoodfacts.org/product/0011...
# 14  http://world-en.openfoodfacts.org/product/0011...
# 15  http://world-en.openfoodfacts.org/product/0011...
# 16  http://world-en.openfoodfacts.org/product/0011...
# 17  http://world-en.openfoodfacts.org/product/0011...
# 18  http://world-en.openfoodfacts.org/product/0011...
# 19  http://world-en.openfoodfacts.org/product/0011...
# 20  http://world-en.openfoodfacts.org/product/0011...
# 21  http://world-en.openfoodfacts.org/product/0011...
# 22  http://world-en.openfoodfacts.org/product/0011...
# 23  http://world-en.openfoodfacts.org/product/0011...
# 24  http://world-en.openfoodfacts.org/product/0011...
# 25  http://world-en.openfoodfacts.org/product/0011...
# 26  http://world-en.openfoodfacts.org/product/0011...
# 27  http://world-en.openfoodfacts.org/product/0011...
# 28  http://world-en.openfoodfacts.org/product/0011...
# 29  http://world-en.openfoodfacts.org/product/0011...
# ..                                                ...
# 47  http://world-en.openfoodfacts.org/product/0011...
# 48  http://world-en.openfoodfacts.org/product/0011...
# 49  http://world-en.openfoodfacts.org/product/0011...
# 50  http://world-en.openfoodfacts.org/product/0011...
# 51  http://world-en.openfoodfacts.org/product/0011...
# 52  http://world-en.openfoodfacts.org/product/0011...
# 53  http://world-en.openfoodfacts.org/product/0011...
# 54  http://world-en.openfoodfacts.org/product/0011...
# 55  http://world-en.openfoodfacts.org/product/0011...
# 56  http://world-en.openfoodfacts.org/product/0011...
# 57  http://world-en.openfoodfacts.org/product/0011...
# 58  http://world-en.openfoodfacts.org/product/0011...
# 59  http://world-en.openfoodfacts.org/product/0011...
# 60  http://world-en.openfoodfacts.org/product/0011...
# 61  http://world-en.openfoodfacts.org/product/0011...
# 62  http://world-en.openfoodfacts.org/product/0011...
# 63  http://world-en.openfoodfacts.org/product/0011...
# 64  http://world-en.openfoodfacts.org/product/0011...
# 65  http://world-en.openfoodfacts.org/product/0011...
# 66  http://world-en.openfoodfacts.org/product/0011...
# 67  http://world-en.openfoodfacts.org/product/0011...
# 68  http://world-en.openfoodfacts.org/product/0011...
# 69  http://world-en.openfoodfacts.org/product/0011...
# 70  http://world-en.openfoodfacts.org/product/0011...
# 71  http://world-en.openfoodfacts.org/product/0011...
# 72  http://world-en.openfoodfacts.org/product/0011...
# 73  http://world-en.openfoodfacts.org/product/0011...
# 74  http://world-en.openfoodfacts.org/product/0041...
# 75  http://world-en.openfoodfacts.org/product/0041...
# 76  http://world-en.openfoodfacts.org/product/0041...
#
# [77 rows x 12 columns]

# %% [markdown]
# # Distributed Queries - finding products based on recipe ingredients

# %% [markdown]
# I would like to run a query to find potential products to use as ingredients in a recipe.  To implement this query I will have to run a query for recipe data against the PostgreSQL database and a query for product data against the MongoDB database and then join the results of the two queries.
#
# I will write a ``DistributedQuery`` class that provides a fluent interface that allows the user to construct queries to run against the products and recipes databases and then performs a join on recipes.ingredient to product.name and returns a joined panda DataFrame.
#
# *example - find kroger-brand products that can be used as ingredients in highly-rated (4+) brunch recipes that contain eggs and bacon and the recipe is under 500 calories*
# ```
# DistributedQuery(products, recipes)\
#     .recipe_category("brunch")\
#     .recipe_ingredients_contains_all_of(["bacon", "egg"])\
#     .recipe_min_rating(4)\
#     .recipe_max_calories(500)\
#     .product_brand("Kroger")\
#     .run()
# ```
#
# To complicate matters, the recipe ingredients array and product name fields do not join nicely.  The ingredient field often contains amount and other descriptive information that makes it difficult to match against product names with high degrees of confidence.  The product name fields also occasionally include brand and other descriptive information that make it difficult to automatically match against a generic ingredient name.  To perform the join I will have to break apart the ingredient and product name fields, join on subsets of the field and then compute a weight value to provide a simple estimation of the confidence of the match.  If my key matching criteria is too strict it will miss products that make sense for an ingredient need, if the key matching criteria is too loose there will be a very large number of false matches.
#
# I will compute weights on the joins and select (by trial and error) a reasonable default minimum weight to use to filter out low-confidence joins.  I will also add a method to the fluent interface ``.min_weight(number)`` that will allow the user to adjust the weight value used to filter out low-confidence joins.

# %%
class DistributedQuery:
    
    '''Provides a fluent API to construct and run queries against the products and recipe databases 
    and does a 'fuzzy' join of the query results on (recipes.ingredients, products.name)'''
    
    def __init__(self, products, recipes):
        self.products_query = products.query()
        self.recipes_query = recipes.query()
        self.min_merge_weight = 0.2
    
    @staticmethod
    def get_text_breakdown(ingredient):
                
        if not ingredient:
            return []
        
        ingredient = ingredient.strip()#.split(',')[0]
        _last = len(ingredient)
        run = True
        parts = []

        while run:
            idx = ingredient.rfind(" ", 0, _last)
            _last = idx

            if idx == -1:
                parts.append(ingredient.lower())
                run = False
            else:
                parts.append(ingredient[idx:].strip(" ,()-").lower())

        return parts
    
    def min_weight(self, weight):
        self.min_merge_weight = weight
        return self
    
    def product_category(self, category):
        self.products_query = self.products_query.category(category)
        return self
    
    def product_max_calories(self, max_calories):
        self.products_query = self.products_query.max_calories(max_calories)
        return self
    
    def product_brand(self, brand):
        self.products_query = self.products_query.brand(brand)
        return self
    
    def recipe_max_calories(self, max_calories):
        self.recipes_query = self.recipes_query.max_calories(max_calories)
        return self
    
    def recipe_min_rating(self, min_rating):
        self.recipes_query = self.recipes_query.min_rating(min_rating)
        return self
    
    def recipe_ingredients_contains_all_of(self, ingredients):
        self.recipes_query = self.recipes_query.ingredient_all_of(ingredients)
        return self
    
    def recipe_category(self, category):
        self.recipes_query = self.recipes_query.category(category)
        return self
    
    def recipe_category_any_of(self, categories):
        self.recipes_query = self.recipes_query.category_any_of(categories)
        return self
    
    def recipe_category_all_of(self, categories):
        self.recipes_query = self.recipes_query.category_all_of(categories)
        return self
    
    @staticmethod
    def products_add_name_key(df):
        df = df.add_prefix("product_")
        rows = []
        _ = df.apply(lambda row: [rows.append(row.tolist()+[name_part]) for name_part in DistributedQuery.get_text_breakdown(row["product_name"])], axis=1)
        return pandas.DataFrame(rows, columns=df.columns.tolist()+['name_key']).drop_duplicates()
    
    @staticmethod
    def recipes_add_ingredient_key(df):
        df = df.add_prefix("recipe_")

        rows = []
        _ = df.apply(lambda row: [rows.append(row.tolist()+[ingredient]) for ingredient in row["recipe_ingredients"]], axis=1)
        _df = pandas.DataFrame(rows, columns=df.columns.tolist()+['recipe_ingredient']).drop_duplicates(['recipe_title','recipe_ingredient'])

        rows = []
        for index, row in _df.iterrows():
            for part in DistributedQuery.get_text_breakdown(row["recipe_ingredient"]):
                rows.append(row.tolist()+[part])
                
        return pandas.DataFrame(rows, columns=_df.columns.tolist()+['ingredient_key']).drop_duplicates(['recipe_title', 'recipe_ingredient', 'ingredient_key'])    
    
    @staticmethod
    def compute_weight(key, field):
        
        if not key or not field:
            return 0
        
        if pandas.isnull(key) or pandas.isnull(field):
            return 0
        
        return len(key)/len(field)
    
    @staticmethod
    def compute_merge_weight(df):
        df['ingredient_key_weight'] = df.apply(lambda row: DistributedQuery.compute_weight(row['ingredient_key'], row['product_name']), axis=1)
        df['name_key_weight'] = df.apply(lambda row: DistributedQuery.compute_weight(row['name_key'], row['recipe_ingredient']), axis=1)        
        return df
    
    @staticmethod
    def merge_recipes_and_products(df_recipes, df_products):        
        df_recipes2 = DistributedQuery.recipes_add_ingredient_key(df_recipes)
        df_products2 = DistributedQuery.products_add_name_key(df_products)
        
        df = pandas.merge(df_recipes2, df_products2, how='left', left_on="ingredient_key", right_on="name_key", suffixes=('_recipe','_product'))
        df = DistributedQuery.compute_merge_weight(df)
        df.drop('ingredient_key', axis=1, inplace=True)
        df.drop('name_key', axis=1, inplace=True)
        df = df.drop_duplicates(['recipe_title', 'recipe_ingredient', 'product_brands', 'product_name'])
        return df
    
    def run(self):
        '''run the queries, merge via 'fuzzy join' and return the merged result as a pandas DataFrame '''
        df_recipes = self.recipes_query.run()
        df_products = self.products_query.run()
        df_merged = self.merge_recipes_and_products(df_recipes, df_products)
        
        if self.min_merge_weight > 0:
            df_merged = df_merged.loc[(df_merged['ingredient_key_weight'] > self.min_merge_weight) 
                                      & (df_merged['name_key_weight'] > self.min_merge_weight)]
        
        return df_merged
    
    def show(self):
        '''return a dictionary showing the recipe and product queries that would be run and merged'''
        return {"products": self.products_query.show(), "recipes": self.recipes_query.show()}

default_columns = ['recipe_title', 'recipe_ingredient', 'recipe_rating', 'recipe_calories', 'product_name', 'product_brands', 'ingredient_key_weight', 'name_key_weight']

def filter_by_recipe_title(df, recipe, columns=default_columns):
    '''helper function to easily filter query results by a recipe name'''
    return df.loc[df['recipe_title'].str.contains(recipe)][columns]

def simplify(df, columns=default_columns):
    '''helper function to reduce data frame to a subset of columns'''
    return df[columns]

# %% [markdown]
# *query - find kroger-brand products that can be used as ingredients in highly-rated (4+) brunch recipes that contain eggs and bacon and for which recipe is under 500 calories*

# %%
# %time df = DistributedQuery(products, recipes)\
    .recipe_category("brunch")\
    .recipe_ingredients_contains_all_of(["bacon", "egg"])\
    .recipe_min_rating(4)\
    .recipe_max_calories(500)\
    .product_brand("Kroger")\
    .run()
# Out:
# CPU times: user 397 ms, sys: 9.47 ms, total: 406 ms
# Wall time: 536 ms

# %%
simplify(df)
# Out:
#                           recipe_title                  recipe_ingredient  \
# 0            Buckwheat Bacon Pancakes             1/2 cup buckwheat flour
# 3            Buckwheat Bacon Pancakes             1/2 cup buckwheat flour
# 15           Buckwheat Bacon Pancakes                    1 teaspoon sugar
# 16           Buckwheat Bacon Pancakes                    1 teaspoon sugar
# 19           Buckwheat Bacon Pancakes            1 teaspoon baking powder
# 22           Buckwheat Bacon Pancakes            1 teaspoon baking powder
# 35           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 36           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 37           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 38           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 44           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 47           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 48           Buckwheat Bacon Pancakes                   1/4 teaspoon salt
# 58           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 59           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 61           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 62           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 63           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 64           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 65           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 66           Buckwheat Bacon Pancakes   1 1/4 cups well-shaken buttermilk
# 121  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 123  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 124  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 125  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 127  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 128  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 129  Creamy Grits with Rosemary Bacon            8 thick-cut bacon slices
# 133  Creamy Grits with Rosemary Bacon                    2 1/2 cups water
# 134  Creamy Grits with Rosemary Bacon                    2 1/2 cups water
# ..                                 ...                                ...
# 847           Baked Eggs with Spinach       2 tablespoons unsalted butter
# 848           Baked Eggs with Spinach       2 tablespoons unsalted butter
# 865           Baked Eggs with Spinach                 1/3 cup heavy cream
# 866           Baked Eggs with Spinach                 1/3 cup heavy cream
# 867           Baked Eggs with Spinach                 1/3 cup heavy cream
# 868           Baked Eggs with Spinach                 1/3 cup heavy cream
# 870           Baked Eggs with Spinach                 1/3 cup heavy cream
# 875           Baked Eggs with Spinach                 1/3 cup heavy cream
# 876           Baked Eggs with Spinach                 1/3 cup heavy cream
# 877           Baked Eggs with Spinach                 1/3 cup heavy cream
# 878           Baked Eggs with Spinach                 1/3 cup heavy cream
# 879           Baked Eggs with Spinach                 1/3 cup heavy cream
# 881           Baked Eggs with Spinach                 1/3 cup heavy cream
# 885           Baked Eggs with Spinach                 1/3 cup heavy cream
# 887           Baked Eggs with Spinach                 1/3 cup heavy cream
# 888           Baked Eggs with Spinach                 1/3 cup heavy cream
# 889           Baked Eggs with Spinach                 1/3 cup heavy cream
# 893           Baked Eggs with Spinach                 1/3 cup heavy cream
# 899           Baked Eggs with Spinach                 1/3 cup heavy cream
# 907           Baked Eggs with Spinach                   1/2 teaspoon salt
# 908           Baked Eggs with Spinach                   1/2 teaspoon salt
# 909           Baked Eggs with Spinach                   1/2 teaspoon salt
# 910           Baked Eggs with Spinach                   1/2 teaspoon salt
# 916           Baked Eggs with Spinach                   1/2 teaspoon salt
# 919           Baked Eggs with Spinach                   1/2 teaspoon salt
# 920           Baked Eggs with Spinach                   1/2 teaspoon salt
# 925           Baked Eggs with Spinach           1/8 teaspoon black pepper
# 928           Baked Eggs with Spinach           1/8 teaspoon black pepper
# 929           Baked Eggs with Spinach           1/8 teaspoon black pepper
# 931           Baked Eggs with Spinach           1/8 teaspoon black pepper
#
#      recipe_rating  recipe_calories  \
# 0            4.375            269.0
# 3            4.375            269.0
# 15           4.375            269.0
# 16           4.375            269.0
# 19           4.375            269.0
# 22           4.375            269.0
# 35           4.375            269.0
# 36           4.375            269.0
# 37           4.375            269.0
# 38           4.375            269.0
# 44           4.375            269.0
# 47           4.375            269.0
# 48           4.375            269.0
# 58           4.375            269.0
# 59           4.375            269.0
# 61           4.375            269.0
# 62           4.375            269.0
# 63           4.375            269.0
# 64           4.375            269.0
# 65           4.375            269.0
# 66           4.375            269.0
# 121          4.375            497.0
# 123          4.375            497.0
# 124          4.375            497.0
# 125          4.375            497.0
# 127          4.375            497.0
# 128          4.375            497.0
# 129          4.375            497.0
# 133          4.375            497.0
# 134          4.375            497.0
# ..             ...              ...
# 847          4.375            229.0
# 848          4.375            229.0
# 865          4.375            229.0
# 866          4.375            229.0
# 867          4.375            229.0
# 868          4.375            229.0
# 870          4.375            229.0
# 875          4.375            229.0
# 876          4.375            229.0
# 877          4.375            229.0
# 878          4.375            229.0
# 879          4.375            229.0
# 881          4.375            229.0
# 885          4.375            229.0
# 887          4.375            229.0
# 888          4.375            229.0
# 889          4.375            229.0
# 893          4.375            229.0
# 899          4.375            229.0
# 907          4.375            229.0
# 908          4.375            229.0
# 909          4.375            229.0
# 910          4.375            229.0
# 916          4.375            229.0
# 919          4.375            229.0
# 920          4.375            229.0
# 925          4.375            229.0
# 928          4.375            229.0
# 929          4.375            229.0
# 931          4.375            229.0
#
#                                        product_name  \
# 0                                 Whole Wheat Flour
# 3                                     Coconut Flour
# 15                                 Dark Brown Sugar
# 16                                Light Brown Sugar
# 19                                     Chili Powder
# 22                                    Baking Powder
# 35                                      Celery Salt
# 36                                       Onion Salt
# 37                                    Seasoned Salt
# 38                                      Garlic Salt
# 44                               Coarse Kosher Salt
# 47                                Free-Flowing Salt
# 48                                     Iodized Salt
# 58                       Cultured Lowfat Buttermilk
# 59   Grade A Pasteurized Cultured Lowfat Buttermilk
# 61                              Cultured Buttermilk
# 62                                Creamy Buttermilk
# 63                             Pancakes, Buttermilk
# 64                   Buttermilk Waffles, Buttermilk
# 65      Complete Pancake And Waffle Mix, Buttermilk
# 66                        Jumbo Biscuits Buttermilk
# 121                             Colby Cheese Slices
# 123                               Aged Swiss Slices
# 124                             Mild Cheddar Slices
# 125                               Mozzarella Slices
# 127                           Bread & Butter Slices
# 128                              Coffee Cake Slices
# 129                          Jellies, Orange Slices
# 133                                   Seltzer Water
# 134                         Sparkling Seltzer Water
# ..                                              ...
# 847                                 Unsalted Butter
# 848                             Salted Light Butter
# 865                            Party Pail Ice Cream
# 866                              Soda, Orange Cream
# 867                             Soda, Vanilla Cream
# 868                                Deluxe Ice Cream
# 870                            Party Pail Ice Cream
# 875                                      Sour Cream
# 876                             Original Sour Cream
# 877                                    Source Cream
# 878                              Natural Sour Cream
# 879                          E-Z Squeeze Sour Cream
# 881                             Fat Free Sour Cream
# 885                                       Ice Cream
# 887                            Heavy Whipping Cream
# 888                            Heavy Whipping Cream
# 889                                  Whipping Cream
# 893                                       Ice Cream
# 899                             Home Team Ice Cream
# 907                                     Celery Salt
# 908                                      Onion Salt
# 909                                   Seasoned Salt
# 910                                     Garlic Salt
# 916                              Coarse Kosher Salt
# 919                               Free-Flowing Salt
# 920                                    Iodized Salt
# 925                                    Lemon Pepper
# 928                   Hot Pepper Cheese, Hot Pepper
# 929                   Garlic & Cracked Black Pepper
# 931                     Jelly, Oregon Pear & Pepper
#
#                          product_brands  ingredient_key_weight  \
# 0                                Kroger               0.294118
# 3                        The Kroger Co.               0.384615
# 15                               Kroger               0.312500
# 16                       The Kroger Co.               0.294118
# 19                               Kroger               0.500000
# 22                               Kroger               0.461538
# 35                               Kroger               0.363636
# 36                               Kroger               0.400000
# 37                               Kroger               0.307692
# 38                               Kroger               0.363636
# 44                               Kroger               0.222222
# 47                               Kroger               0.235294
# 48                               Kroger               0.333333
# 58              Kroger,  The Kroger Co.               0.384615
# 59              Kroger,  The Kroger Co.               0.217391
# 61              Kroger,  The Kroger Co.               0.526316
# 62                               Kroger               0.588235
# 63                               Kroger               0.500000
# 64                               Kroger               0.333333
# 65                               Kroger               0.232558
# 66                               Kroger               0.400000
# 121                              Kroger               0.315789
# 123                              Kroger               0.352941
# 124                              Kroger               0.315789
# 125                              Kroger               0.352941
# 127                              Kroger               0.285714
# 128                              Kroger               0.333333
# 129                              Kroger               0.272727
# 133             Kroger,  The Kroger Co.               0.384615
# 134                      The Kroger Co.               0.217391
# ..                                  ...                    ...
# 847                              Kroger               0.400000
# 848                              Kroger               0.315789
# 865                              Kroger               0.250000
# 866              Big K,  The Kroger Co.               0.277778
# 867              Big K,  The Kroger Co.               0.263158
# 868                      The Kroger Co.               0.312500
# 870                      The Kroger Co.               0.250000
# 875                              Kroger               0.500000
# 876                              Kroger               0.263158
# 877                              Kroger               0.416667
# 878                              Kroger               0.277778
# 879                              Kroger               0.227273
# 881                              Kroger               0.263158
# 885                      The Kroger Co.               0.555556
# 887                              Kroger               0.250000
# 888             Kroger,  The Kroger Co.               0.250000
# 889             Kroger,  The Kroger Co.               0.357143
# 893                              Kroger               0.555556
# 899                              Kroger               0.263158
# 907                              Kroger               0.363636
# 908                              Kroger               0.400000
# 909                              Kroger               0.307692
# 910                              Kroger               0.363636
# 916                              Kroger               0.222222
# 919                              Kroger               0.235294
# 920                              Kroger               0.333333
# 925                              Kroger               0.500000
# 928                              Kroger               0.206897
# 929                              Kroger               0.206897
# 931  Private Selection,  The Kroger Co.               0.222222
#
#      name_key_weight
# 0           0.217391
# 3           0.217391
# 15          0.312500
# 16          0.312500
# 19          0.250000
# 22          0.250000
# 35          0.235294
# 36          0.235294
# 37          0.235294
# 38          0.235294
# 44          0.235294
# 47          0.235294
# 48          0.235294
# 58          0.303030
# 59          0.303030
# 61          0.303030
# 62          0.303030
# 63          0.303030
# 64          0.303030
# 65          0.303030
# 66          0.303030
# 121         0.250000
# 123         0.250000
# 124         0.250000
# 125         0.250000
# 127         0.250000
# 128         0.250000
# 129         0.250000
# 133         0.312500
# 134         0.312500
# ..               ...
# 847         0.206897
# 848         0.206897
# 865         0.263158
# 866         0.263158
# 867         0.263158
# 868         0.263158
# 870         0.263158
# 875         0.263158
# 876         0.263158
# 877         0.263158
# 878         0.263158
# 879         0.263158
# 881         0.263158
# 885         0.263158
# 887         0.263158
# 888         0.263158
# 889         0.263158
# 893         0.263158
# 899         0.263158
# 907         0.235294
# 908         0.235294
# 909         0.235294
# 910         0.235294
# 916         0.235294
# 919         0.235294
# 920         0.235294
# 925         0.240000
# 928         0.240000
# 929         0.240000
# 931         0.240000
#
# [139 rows x 8 columns]

# %% [markdown]
# *Re-run the query, this time looking for Safeway-brand products*

# %%
# %time df2 = DistributedQuery(products, recipes)\
    .recipe_category("brunch")\
    .recipe_ingredients_contains_all_of(["bacon", "egg"])\
    .recipe_min_rating(4)\
    .recipe_max_calories(500)\
    .product_brand("Safeway")\
    .run()
# Out:
# CPU times: user 182 ms, sys: 3.38 ms, total: 185 ms
# Wall time: 305 ms

# %%
simplify(df2)
# Out:
#                                           recipe_title  \
# 0                            Buckwheat Bacon Pancakes
# 10                           Buckwheat Bacon Pancakes
# 11                           Buckwheat Bacon Pancakes
# 14                           Buckwheat Bacon Pancakes
# 46                           Buckwheat Bacon Pancakes
# 48                           Buckwheat Bacon Pancakes
# 49                           Buckwheat Bacon Pancakes
# 89                   Creamy Grits with Rosemary Bacon
# 96                   Creamy Grits with Rosemary Bacon
# 97                   Creamy Grits with Rosemary Bacon
# 101                  Creamy Grits with Rosemary Bacon
# 102                  Creamy Grits with Rosemary Bacon
# 104                  Creamy Grits with Rosemary Bacon
# 106                  Creamy Grits with Rosemary Bacon
# 108                  Creamy Grits with Rosemary Bacon
# 110                  Creamy Grits with Rosemary Bacon
# 111                  Creamy Grits with Rosemary Bacon
# 113                  Creamy Grits with Rosemary Bacon
# 115                  Creamy Grits with Rosemary Bacon
# 116                  Creamy Grits with Rosemary Bacon
# 118                  Creamy Grits with Rosemary Bacon
# 119                  Creamy Grits with Rosemary Bacon
# 120                  Creamy Grits with Rosemary Bacon
# 121                  Creamy Grits with Rosemary Bacon
# 140                  Creamy Grits with Rosemary Bacon
# 142                  Creamy Grits with Rosemary Bacon
# 147                  Creamy Grits with Rosemary Bacon
# 148                  Creamy Grits with Rosemary Bacon
# 149                  Creamy Grits with Rosemary Bacon
# 230                                         Leek Tart
# 231                                         Leek Tart
# 232                                         Leek Tart
# 244  Vidalia Onion Tart with Bacon, Local Honey, an...
# 384  Potato-Crusted Quiche with Smoked Cheddar and ...
# 390  Potato-Crusted Quiche with Smoked Cheddar and ...
# 430            Bacon, Egg, and Tomato Club Sandwiches
# 518        Frisée Salad with Lardons and Poached Eggs
# 519        Frisée Salad with Lardons and Poached Eggs
# 530                           Baked Eggs with Spinach
# 532                           Baked Eggs with Spinach
# 537                           Baked Eggs with Spinach
# 538                           Baked Eggs with Spinach
# 539                           Baked Eggs with Spinach
# 557                           Baked Eggs with Spinach
# 559                           Baked Eggs with Spinach
# 560                           Baked Eggs with Spinach
# 562                           Baked Eggs with Spinach
# 563                           Baked Eggs with Spinach
# 564                           Baked Eggs with Spinach
# 573                           Baked Eggs with Spinach
#
#                      recipe_ingredient  recipe_rating  recipe_calories  \
# 0              1/2 cup buckwheat flour          4.375            269.0
# 10                    1 teaspoon sugar          4.375            269.0
# 11                    1 teaspoon sugar          4.375            269.0
# 14            1 teaspoon baking powder          4.375            269.0
# 46   1 1/4 cups well-shaken buttermilk          4.375            269.0
# 48   1 1/4 cups well-shaken buttermilk          4.375            269.0
# 49   1 1/4 cups well-shaken buttermilk          4.375            269.0
# 89            8 thick-cut bacon slices          4.375            497.0
# 96            8 thick-cut bacon slices          4.375            497.0
# 97            8 thick-cut bacon slices          4.375            497.0
# 101                   2 1/2 cups water          4.375            497.0
# 102                   2 1/2 cups water          4.375            497.0
# 104                   2 1/2 cups water          4.375            497.0
# 106                   2 1/2 cups water          4.375            497.0
# 108                   2 1/2 cups water          4.375            497.0
# 110                   2 1/2 cups water          4.375            497.0
# 111                   2 1/2 cups water          4.375            497.0
# 113                   2 1/2 cups water          4.375            497.0
# 115                   2 1/2 cups water          4.375            497.0
# 116                   2 1/2 cups water          4.375            497.0
# 118                   2 1/2 cups water          4.375            497.0
# 119                   2 1/2 cups water          4.375            497.0
# 120                   2 1/2 cups water          4.375            497.0
# 121                   2 1/2 cups water          4.375            497.0
# 140       1 tablespoon unsalted butter          4.375            497.0
# 142       1 tablespoon unsalted butter          4.375            497.0
# 147       1 tablespoon unsalted butter          4.375            497.0
# 148       1 tablespoon unsalted butter          4.375            497.0
# 149       1 tablespoon unsalted butter          4.375            497.0
# 230                 2/3 cup whole milk          4.375            262.0
# 231                 2/3 cup whole milk          4.375            262.0
# 232                 2/3 cup whole milk          4.375            262.0
# 244           3 cups all-purpose flour          4.375            455.0
# 384                1 cup chopped onion          4.375            487.0
# 390      1 cup chopped red bell pepper          4.375            487.0
# 430                 1/2 cup mayonnaise          4.375            472.0
# 518     3 tablespoons red-wine vinegar          5.000            269.0
# 519     3 tablespoons red-wine vinegar          5.000            269.0
# 530      2 tablespoons unsalted butter          4.375            229.0
# 532      2 tablespoons unsalted butter          4.375            229.0
# 537      2 tablespoons unsalted butter          4.375            229.0
# 538      2 tablespoons unsalted butter          4.375            229.0
# 539      2 tablespoons unsalted butter          4.375            229.0
# 557                1/3 cup heavy cream          4.375            229.0
# 559                1/3 cup heavy cream          4.375            229.0
# 560                1/3 cup heavy cream          4.375            229.0
# 562                1/3 cup heavy cream          4.375            229.0
# 563                1/3 cup heavy cream          4.375            229.0
# 564                1/3 cup heavy cream          4.375            229.0
# 573          1/8 teaspoon black pepper          4.375            229.0
#
#                            product_name                      product_brands  \
# 0                     All Purpose Flour                       Safeway  Inc.
# 10                    Light Brown Sugar  Signature Kitchens,  Safeway  Inc.
# 11                     Dark Brown Sugar                       Safeway  Inc.
# 14                         Chili Powder                             Safeway
# 46           Lowfat Cultured Buttermilk                       Safeway  Inc.
# 48   Enriched Bread, Country Buttermilk  Signature Kitchens,  Safeway  Inc.
# 49     Enriched Wheat Bread, Buttermilk  Signature Kitchens,  Safeway  Inc.
# 89        Dried Philippine Mango Slices      Safeway Select,  Safeway  Inc.
# 96                Assorted Fruit Slices             Safeway,  Safeway  Inc.
# 97             Candy, Watermelon Slices  Signature Kitchens,  Safeway  Inc.
# 101                Refreshe Tonic Water                    Refreshe,Safeway
# 102             refreshe drinking water                    refreshe,Safeway
# 104             Purified Drinking Water            Refreshe,  Safeway  Inc.
# 106             Purified Drinking Water                       Safeway  Inc.
# 108                   Electrolyte Water                             Safeway
# 110                   Electrolyte Water                       Safeway  Inc.
# 111                  Electrolyte* Water                       Safeway  Inc.
# 113                       Seltzer Water            Refreshe,  Safeway  Inc.
# 115                  Lime Seltzer Water            Refreshe,  Safeway  Inc.
# 116                        Spring Water            Refreshe,  Safeway  Inc.
# 118                       Seltzer Water                       Safeway  Inc.
# 119                    Diet Tonic Water            Refreshe,  Safeway  Inc.
# 120                        Spring Water                       Safeway  Inc.
# 121                         Tonic Water            Refreshe,  Safeway  Inc.
# 140                  Sweet Cream Butter             Lucerne,  Safeway  Inc.
# 142           Croutons, Garlic & Butter  Signature Kitchens,  Safeway  Inc.
# 147                        Apple Butter  Signature Kitchens,  Safeway  Inc.
# 148                       Peanut Butter                       Safeway  Inc.
# 149        No stir Creamy Peanut Butter              Organics,Safeway,Von's
# 230                        Coconut Milk  Signature Kitchens,  Safeway  Inc.
# 231                   Lite Coconut Milk  Signature Kitchens,  Safeway  Inc.
# 232                                Milk                       Safeway  Inc.
# 244                   All Purpose Flour                       Safeway  Inc.
# 384                       Bagels, Onion  Signature Kitchens,  Safeway  Inc.
# 390              Marinade, Lemon Pepper  Signature Kitchens,  Safeway  Inc.
# 430       Pantry Essentials, Mayonnaise                       Safeway  Inc.
# 518               Seasoned Rice Vinegar    Safeway Kitchens,  Safeway  Inc.
# 519                Reserve Rose Vinegar      Safeway Select,  Safeway  Inc.
# 530                  Sweet Cream Butter             Lucerne,  Safeway  Inc.
# 532           Croutons, Garlic & Butter  Signature Kitchens,  Safeway  Inc.
# 537                        Apple Butter  Signature Kitchens,  Safeway  Inc.
# 538                       Peanut Butter                       Safeway  Inc.
# 539        No stir Creamy Peanut Butter              Organics,Safeway,Von's
# 557                         Light Cream             Lucerne,  Safeway  Inc.
# 559                 Fat Free Sour Cream             Lucerne,  Safeway  Inc.
# 560                           Ice Cream                       Safeway  Inc.
# 562                   Vanilla Ice Cream                       Safeway  Inc.
# 563              Butter Pecan Ice Cream                       Safeway  Inc.
# 564                Strawberry Ice Cream    Signature Select,  Safeway  Inc.
# 573              Marinade, Lemon Pepper  Signature Kitchens,  Safeway  Inc.
#
#      ingredient_key_weight  name_key_weight
# 0                 0.294118         0.217391
# 10                0.294118         0.312500
# 11                0.312500         0.312500
# 14                0.500000         0.250000
# 46                0.384615         0.303030
# 48                0.294118         0.303030
# 49                0.312500         0.303030
# 89                0.206897         0.250000
# 96                0.285714         0.250000
# 97                0.250000         0.250000
# 101               0.250000         0.312500
# 102               0.217391         0.312500
# 104               0.217391         0.312500
# 106               0.217391         0.312500
# 108               0.294118         0.312500
# 110               0.294118         0.312500
# 111               0.277778         0.312500
# 113               0.384615         0.312500
# 115               0.277778         0.312500
# 116               0.416667         0.312500
# 118               0.384615         0.312500
# 119               0.312500         0.312500
# 120               0.416667         0.312500
# 121               0.454545         0.312500
# 140               0.333333         0.214286
# 142               0.240000         0.214286
# 147               0.500000         0.214286
# 148               0.461538         0.214286
# 149               0.214286         0.214286
# 230               0.333333         0.222222
# 231               0.235294         0.222222
# 232               1.000000         0.222222
# 244               0.294118         0.208333
# 384               0.384615         0.263158
# 390               0.272727         0.206897
# 430               0.344828         0.555556
# 518               0.333333         0.233333
# 519               0.350000         0.233333
# 530               0.333333         0.206897
# 532               0.240000         0.206897
# 537               0.500000         0.206897
# 538               0.461538         0.206897
# 539               0.214286         0.206897
# 557               0.454545         0.263158
# 559               0.263158         0.263158
# 560               0.555556         0.263158
# 562               0.294118         0.263158
# 563               0.227273         0.263158
# 564               0.250000         0.263158
# 573               0.272727         0.240000

# %% [markdown]
# try the product, recipe, and distributedQuery interfaces yourself!
#
# examples:
# - ``products.query().name_includes("honey").brand("Trader Joe's").max_sugar(75).run()``
# - ``recipes.query().category_any_of(["easter", "christmas", "thanksgiving"]).min_rating(4).run()``
# - ``DistributedQuery(products, recipes)\
# .recipe_category("christmas")\
# .recipe_min_rating(4)\
# .recipe_max_calories(500)\
# .product_brand("Trader Joe's")\
# .run()``
